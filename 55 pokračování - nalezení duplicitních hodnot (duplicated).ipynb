# %%
import pandas as pd

# %%
employees = pd.read_csv("data/employees.csv").dropna(how="all")
employees
# Out:
#      id_employee  gender  start date  insurance  salary  rise_salary  \
# 0              1    Male  11/26/2023      False  356619          6.9
# 1              2  Female   1/27/2024       True  626147         13.0
# 2              3  Female   3/30/2023       True  332593          6.3
# 3              4    Male    1/8/2024       True  325067          9.9
# 4              5  Female   4/15/2024      False  667828         13.6
# ..           ...     ...         ...        ...     ...          ...
# 995          996  Female   3/31/2023      False  377851         12.0
# 996          997  Female    1/5/2024      False  620298         12.8
# 997          998     NaN   3/16/2024      False  361957         13.3
# 998          999    Male   7/20/2023      False  466946         12.6
# 999         1000    Male   8/30/2023       True  499784          7.4
#
#              department
# 0               Support
# 1           Engineering
# 2               Support
# 3       Human Resources
# ...

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_employee  1000 non-null   int64
#  1   gender       930 non-null    object
#  2   start date   1000 non-null   object
#  3   insurance    1000 non-null   bool
#  4   salary       1000 non-null   int64
#  5   rise_salary  1000 non-null   float64
#  6   department   1000 non-null   object
# dtypes: bool(1), float64(1), int64(2), object(3)
# memory usage: 48.0+ KB

# %% [markdown]
# ? dá se něco převést na kategorie? (když jsou velká data rozdělená do málo kategorií) – gender na kategorie
#
# ? dá se něco převést na časový údaj? – pro budoucí lepší pracování – na datový typ datum – start date
#
# ? dá se něco převést na Bolean – zde už máme Insurance jako Bolean

# %%
employees.gender = employees.gender.astype("category")
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_employee  1000 non-null   int64
#  1   gender       930 non-null    category
#  2   start date   1000 non-null   object
#  3   insurance    1000 non-null   bool
#  4   salary       1000 non-null   int64
#  5   rise_salary  1000 non-null   float64
#  6   department   1000 non-null   object
# dtypes: bool(1), category(1), float64(1), int64(2), object(2)
# memory usage: 41.5+ KB

# %%
pd.to_datetime(employees["start date"], format="%m/%d/%Y")
employees["start date"] = pd.to_datetime(employees["start date"], format="%m/%d/%Y")

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_employee  1000 non-null   int64
#  1   gender       930 non-null    category
#  2   start date   1000 non-null   datetime64[ns]
#  3   insurance    1000 non-null   bool
#  4   salary       1000 non-null   int64
#  5   rise_salary  1000 non-null   float64
#  6   department   1000 non-null   object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 41.5+ KB

# %% [markdown]
# alternativní zápis převodu na datum

# %%
employees2 = pd.read_csv("data/employees.csv", parse_dates=["start date"], date_format="%m/%d/%Y")
employees2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_employee  1000 non-null   int64
#  1   gender       930 non-null    object
#  2   start date   1000 non-null   datetime64[ns]
#  3   insurance    1000 non-null   bool
#  4   salary       1000 non-null   int64
#  5   rise_salary  1000 non-null   float64
#  6   department   1000 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 48.0+ KB

# %% [markdown]
# Pokračování - filtrování dat pomocí a zároveň

# %%
is_female = employees.gender == "Female"
is_in_support = employees.department == "Support"
salary_over_500k = employees.salary >= 500000
have_insurance = employees.insurance == True

# %%
is_female & is_in_support
employees[is_female & is_in_support]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary department
# 2              3  Female 2023-03-30       True  332593          6.3    Support
# 41            42  Female 2024-02-21      False  617534         13.7    Support
# 58            59  Female 2024-05-10      False  584882          9.0    Support
# 64            65  Female 2023-06-18      False  753501          7.3    Support
# 127          128  Female 2023-04-18      False  631743          9.4    Support
# 155          156  Female 2023-02-23       True  355814          5.5    Support
# 203          204  Female 2024-04-08      False  604025          7.2    Support
# 212          213  Female 2024-01-13       True  697679          7.0    Support
# 258          259  Female 2023-04-22      False  684027         13.8    Support
# 269          270  Female 2024-02-02       True  597540         10.1    Support
# 291          292  Female 2023-02-17       True  790241         12.3    Support
# ...

# %%
employees[is_female & have_insurance]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 1              2  Female 2024-01-27       True  626147         13.0
# 2              3  Female 2023-03-30       True  332593          6.3
# 10            11  Female 2023-10-31       True  448591          5.5
# 13            14  Female 2023-11-13       True  717387          7.4
# 17            18  Female 2023-09-21       True  732378         12.5
# ..           ...     ...        ...        ...     ...          ...
# 972          973  Female 2023-03-08       True  332217         10.2
# 975          976  Female 2024-01-07       True  753959          8.8
# 976          977  Female 2024-01-03       True  373133         14.5
# 979          980  Female 2023-12-26       True  397030         11.7
# 985          986  Female 2023-04-23       True  768877          7.9
#
#                department
# 1             Engineering
# 2                 Support
# 10              Marketing
# 13        Human Resources
# ...

# %%
employees[is_female & is_in_support & salary_over_500k]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary department
# 41            42  Female 2024-02-21      False  617534         13.7    Support
# 58            59  Female 2024-05-10      False  584882          9.0    Support
# 64            65  Female 2023-06-18      False  753501          7.3    Support
# 127          128  Female 2023-04-18      False  631743          9.4    Support
# 203          204  Female 2024-04-08      False  604025          7.2    Support
# 212          213  Female 2024-01-13       True  697679          7.0    Support
# 258          259  Female 2023-04-22      False  684027         13.8    Support
# 269          270  Female 2024-02-02       True  597540         10.1    Support
# 291          292  Female 2023-02-17       True  790241         12.3    Support
# 341          342  Female 2023-12-13       True  672484          5.8    Support
# 352          353  Female 2024-05-14       True  676846          9.1    Support
# ...

# %% [markdown]
# úkol - všichni muži, kteří mají větší mzdu než 600k a jsou to prodejci (sales)

# %%
is_male = employees.gender == "Male"
salary_over_600k = employees.salary >= 600000
is_in_sales = employees.department == "Sales"

# %%
employees[is_male & salary_over_600k & is_in_sales]
# Out:
#      id_employee gender start date  insurance  salary  rise_salary department
# 60            61   Male 2023-07-04      False  743284          9.7      Sales
# 171          172   Male 2024-03-07       True  715141         12.7      Sales
# 225          226   Male 2024-04-05       True  788188         13.9      Sales
# 235          236   Male 2024-02-25      False  665988         11.7      Sales
# 263          264   Male 2023-09-11       True  718958          7.6      Sales
# 296          297   Male 2023-11-22      False  762945          7.8      Sales
# 324          325   Male 2023-11-03       True  629692         12.0      Sales
# 400          401   Male 2024-04-12      False  732541          5.9      Sales
# 514          515   Male 2023-08-24      False  647929          9.3      Sales
# 900          901   Male 2023-12-29      False  799578          8.2      Sales

# %% [markdown]
# filtrování pomocí nebo

# %%
# znova jsem si vytáhnul připravené sloupce

is_female = employees.gender == 'Female'
is_in_support = employees.department == 'Support'
salary_over_500k = employees.salary >= 500000
have_insurance = employees.insurance == True
is_male = employees.gender == 'Male'
salary_over_600k = employees.salary >= 600000
is_in_sales = employees.department == 'Sales'

# %%
employees[is_female | have_insurance]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 1              2  Female 2024-01-27       True  626147         13.0
# 2              3  Female 2023-03-30       True  332593          6.3
# 3              4    Male 2024-01-08       True  325067          9.9
# 4              5  Female 2024-04-15      False  667828         13.6
# 6              7    Male 2024-01-19       True  375881          6.9
# ..           ...     ...        ...        ...     ...          ...
# 993          994    Male 2023-05-04       True  795280          7.2
# 994          995  Female 2023-08-19      False  433879         14.3
# 995          996  Female 2023-03-31      False  377851         12.0
# 996          997  Female 2024-01-05      False  620298         12.8
# 999         1000    Male 2023-08-30       True  499784          7.4
#
#              department
# 1           Engineering
# 2               Support
# 3       Human Resources
# 4    Product Management
# ...

# %%
employees[is_in_support | salary_over_600k]
# Out:
#      id_employee      gender start date  insurance  salary  rise_salary  \
# 0              1        Male 2023-11-26      False  356619          6.9
# 1              2      Female 2024-01-27       True  626147         13.0
# 2              3      Female 2023-03-30       True  332593          6.3
# 4              5      Female 2024-04-15      False  667828         13.6
# 8              9  Polygender 2023-10-09      False  694415          7.3
# ..           ...         ...        ...        ...     ...          ...
# 988          989        Male 2023-04-02      False  757385          8.4
# 989          990        Male 2024-02-23       True  332813         14.0
# 991          992        Male 2024-02-14       True  687303          8.5
# 993          994        Male 2023-05-04       True  795280          7.2
# 996          997      Female 2024-01-05      False  620298         12.8
#
#              department
# 0               Support
# 1           Engineering
# 2               Support
# ...

# %%
employees[is_male | is_in_support | have_insurance]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 0              1    Male 2023-11-26      False  356619          6.9
# 1              2  Female 2024-01-27       True  626147         13.0
# 2              3  Female 2023-03-30       True  332593          6.3
# 3              4    Male 2024-01-08       True  325067          9.9
# 5              6    Male 2024-01-26      False  579460          5.6
# ..           ...     ...        ...        ...     ...          ...
# 990          991    Male 2023-05-21       True  316101         12.7
# 991          992    Male 2024-02-14       True  687303          8.5
# 993          994    Male 2023-05-04       True  795280          7.2
# 998          999    Male 2023-07-20      False  466946         12.6
# 999         1000    Male 2023-08-30       True  499784          7.4
#
#           department
# 0            Support
# 1        Engineering
# 2            Support
# 3    Human Resources
# 5           Services
# ...

# %% [markdown]
# Metoda isin

# %%
sales = employees["department"] == "Sales"
engineering = employees["department"] == "Engineering"
product_mamagement = employees["department"] == "Product Management"

# %%
employees[sales | engineering | product_mamagement]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 1              2  Female 2024-01-27       True  626147         13.0
# 4              5  Female 2024-04-15      False  667828         13.6
# 6              7    Male 2024-01-19       True  375881          6.9
# 20            21    Male 2023-03-05      False  374407          5.5
# 23            24  Female 2023-03-07      False  737600          7.5
# ..           ...     ...        ...        ...     ...          ...
# 994          995  Female 2023-08-19      False  433879         14.3
# 996          997  Female 2024-01-05      False  620298         12.8
# 997          998     NaN 2024-03-16      False  361957         13.3
# 998          999    Male 2023-07-20      False  466946         12.6
# 999         1000    Male 2023-08-30       True  499784          7.4
#
#              department
# 1           Engineering
# 4    Product Management
# 6           Engineering
# 20          Engineering
# ...

# %%
departments = sales | engineering | product_mamagement
employees[departments]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 1              2  Female 2024-01-27       True  626147         13.0
# 4              5  Female 2024-04-15      False  667828         13.6
# 6              7    Male 2024-01-19       True  375881          6.9
# 20            21    Male 2023-03-05      False  374407          5.5
# 23            24  Female 2023-03-07      False  737600          7.5
# ..           ...     ...        ...        ...     ...          ...
# 994          995  Female 2023-08-19      False  433879         14.3
# 996          997  Female 2024-01-05      False  620298         12.8
# 997          998     NaN 2024-03-16      False  361957         13.3
# 998          999    Male 2023-07-20      False  466946         12.6
# 999         1000    Male 2023-08-30       True  499784          7.4
#
#              department
# 1           Engineering
# 4    Product Management
# 6           Engineering
# 20          Engineering
# ...

# %%
employees["department"].isin(["Sales", "Engineering", "Product Management"])
employees[employees["department"].isin(["Sales", "Engineering", "Product Management"])]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 1              2  Female 2024-01-27       True  626147         13.0
# 4              5  Female 2024-04-15      False  667828         13.6
# 6              7    Male 2024-01-19       True  375881          6.9
# 20            21    Male 2023-03-05      False  374407          5.5
# 23            24  Female 2023-03-07      False  737600          7.5
# ..           ...     ...        ...        ...     ...          ...
# 994          995  Female 2023-08-19      False  433879         14.3
# 996          997  Female 2024-01-05      False  620298         12.8
# 997          998     NaN 2024-03-16      False  361957         13.3
# 998          999    Male 2023-07-20      False  466946         12.6
# 999         1000    Male 2023-08-30       True  499784          7.4
#
#              department
# 1           Engineering
# 4    Product Management
# 6           Engineering
# 20          Engineering
# ...

# %% [markdown]
# isnull a notnull

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_employee  1000 non-null   int64
#  1   gender       930 non-null    category
#  2   start date   1000 non-null   datetime64[ns]
#  3   insurance    1000 non-null   bool
#  4   salary       1000 non-null   int64
#  5   rise_salary  1000 non-null   float64
#  6   department   1000 non-null   object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 41.5+ KB

# %%
employees
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 0              1    Male 2023-11-26      False  356619          6.9
# 1              2  Female 2024-01-27       True  626147         13.0
# 2              3  Female 2023-03-30       True  332593          6.3
# 3              4    Male 2024-01-08       True  325067          9.9
# 4              5  Female 2024-04-15      False  667828         13.6
# ..           ...     ...        ...        ...     ...          ...
# 995          996  Female 2023-03-31      False  377851         12.0
# 996          997  Female 2024-01-05      False  620298         12.8
# 997          998     NaN 2024-03-16      False  361957         13.3
# 998          999    Male 2023-07-20      False  466946         12.6
# 999         1000    Male 2023-08-30       True  499784          7.4
#
#              department
# 0               Support
# 1           Engineering
# 2               Support
# 3       Human Resources
# ...

# %%
employees.isnull()      # False = existující, True = neexistující
# Out:
#      id_employee  gender  start date  insurance  salary  rise_salary  \
# 0          False   False       False      False   False        False
# 1          False   False       False      False   False        False
# 2          False   False       False      False   False        False
# 3          False   False       False      False   False        False
# 4          False   False       False      False   False        False
# ..           ...     ...         ...        ...     ...          ...
# 995        False   False       False      False   False        False
# 996        False   False       False      False   False        False
# 997        False    True       False      False   False        False
# 998        False   False       False      False   False        False
# 999        False   False       False      False   False        False
#
#      department
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# ...

# %%
employees.notnull()     # True = existující hodnoty, False = neexistující
# Out:
#      id_employee  gender  start date  insurance  salary  rise_salary  \
# 0           True    True        True       True    True         True
# 1           True    True        True       True    True         True
# 2           True    True        True       True    True         True
# 3           True    True        True       True    True         True
# 4           True    True        True       True    True         True
# ..           ...     ...         ...        ...     ...          ...
# 995         True    True        True       True    True         True
# 996         True    True        True       True    True         True
# 997         True   False        True       True    True         True
# 998         True    True        True       True    True         True
# 999         True    True        True       True    True         True
#
#      department
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ..          ...
# ...

# %%
employees["gender"].isnull()

employees[employees["gender"].isnull()]
# Out:
#      id_employee gender start date  insurance  salary  rise_salary  \
# 28            29    NaN 2024-05-10       True  725075          5.5
# 32            33    NaN 2023-05-30       True  774991          8.0
# 61            62    NaN 2023-10-07      False  435796         11.3
# 72            73    NaN 2024-04-05       True  586641         13.8
# 75            76    NaN 2023-10-09       True  520527          5.1
# ..           ...    ...        ...        ...     ...          ...
# 877          878    NaN 2023-07-01      False  478343         11.7
# 884          885    NaN 2024-03-22      False  522716         12.1
# 931          932    NaN 2024-02-11      False  692645         11.0
# 965          966    NaN 2023-07-31      False  650028          9.6
# 997          998    NaN 2024-03-16      False  361957         13.3
#
#                    department
# 28         Product Management
# 32       Business Development
# 61                    Support
# 72                  Marketing
# ...

# %%
employees["gender"].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997    False
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
employees[employees["gender"].notnull()]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 0              1    Male 2023-11-26      False  356619          6.9
# 1              2  Female 2024-01-27       True  626147         13.0
# 2              3  Female 2023-03-30       True  332593          6.3
# 3              4    Male 2024-01-08       True  325067          9.9
# 4              5  Female 2024-04-15      False  667828         13.6
# ..           ...     ...        ...        ...     ...          ...
# 994          995  Female 2023-08-19      False  433879         14.3
# 995          996  Female 2023-03-31      False  377851         12.0
# 996          997  Female 2024-01-05      False  620298         12.8
# 998          999    Male 2023-07-20      False  466946         12.6
# 999         1000    Male 2023-08-30       True  499784          7.4
#
#              department
# 0               Support
# 1           Engineering
# 2               Support
# 3       Human Resources
# ...

# %%
my_dataframe = pd.DataFrame()
my_dataframe["isnull"] = employees["gender"].isnull()
my_dataframe["notnull"] = employees["gender"].notnull()
my_dataframe
# Out:
#      isnull  notnull
# 0     False     True
# 1     False     True
# 2     False     True
# 3     False     True
# 4     False     True
# ..      ...      ...
# 995   False     True
# 996   False     True
# 997    True    False
# 998   False     True
# 999   False     True
#
# [1000 rows x 2 columns]

# %%
employees["department"].isnull()
employees[employees["department"].isnull()]

employees["department"].notnull()
employees[employees["department"].notnull()]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 0              1    Male 2023-11-26      False  356619          6.9
# 1              2  Female 2024-01-27       True  626147         13.0
# 2              3  Female 2023-03-30       True  332593          6.3
# 3              4    Male 2024-01-08       True  325067          9.9
# 4              5  Female 2024-04-15      False  667828         13.6
# ..           ...     ...        ...        ...     ...          ...
# 995          996  Female 2023-03-31      False  377851         12.0
# 996          997  Female 2024-01-05      False  620298         12.8
# 997          998     NaN 2024-03-16      False  361957         13.3
# 998          999    Male 2023-07-20      False  466946         12.6
# 999         1000    Male 2023-08-30       True  499784          7.4
#
#              department
# 0               Support
# 1           Engineering
# 2               Support
# 3       Human Resources
# ...

# %% [markdown]
# between (hodnoty mezi)

# %%
# hodnoty jsou včetně 300 000 a 400 000!
employees["salary"].between(300000, 400000)
employees[employees["salary"].between(300000, 400000)]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 0              1    Male 2023-11-26      False  356619          6.9
# 2              3  Female 2023-03-30       True  332593          6.3
# 3              4    Male 2024-01-08       True  325067          9.9
# 6              7    Male 2024-01-19       True  375881          6.9
# 15            16    Male 2024-03-16      False  323687         13.5
# ..           ...     ...        ...        ...     ...          ...
# 987          988    Male 2023-12-31      False  321271         11.0
# 989          990    Male 2024-02-23       True  332813         14.0
# 990          991    Male 2023-05-21       True  316101         12.7
# 995          996  Female 2023-03-31      False  377851         12.0
# 997          998     NaN 2024-03-16      False  361957         13.3
#
#              department
# 0               Support
# 2               Support
# 3       Human Resources
# 6           Engineering
# ...

# %%
min_date = pd.to_datetime("2023-01-01")
max_date = pd. to_datetime("2023-12-31")
min_date
max_date
employees["start date"].between(min_date, max_date)
employees[employees["start date"].between(min_date, max_date)]
# Out:
#      id_employee      gender start date  insurance  salary  rise_salary  \
# 0              1        Male 2023-11-26      False  356619          6.9
# 2              3      Female 2023-03-30       True  332593          6.3
# 7              8        Male 2023-04-01      False  459264         12.6
# 8              9  Polygender 2023-10-09      False  694415          7.3
# 9             10  Non-binary 2023-05-25       True  439208          8.4
# ..           ...         ...        ...        ...     ...          ...
# 993          994        Male 2023-05-04       True  795280          7.2
# 994          995      Female 2023-08-19      False  433879         14.3
# 995          996      Female 2023-03-31      False  377851         12.0
# 998          999        Male 2023-07-20      False  466946         12.6
# 999         1000        Male 2023-08-30       True  499784          7.4
#
#           department
# 0            Support
# 2            Support
# 7    Human Resources
# ...

# %%
employees.rise_salary.max()
employees.rise_salary.between(14.0, 15.0)
employees[employees.rise_salary.between(14.0, 15.0)]
# Out:
#      id_employee    gender start date  insurance  salary  rise_salary  \
# 35            36    Female 2023-10-04       True  710441         14.7
# 38            39      Male 2023-10-31      False  729174         14.6
# 53            54      Male 2023-08-07      False  418601         15.0
# 70            71      Male 2023-10-27      False  584607         14.1
# 78            79  Bigender 2023-04-13       True  584995         14.7
# ..           ...       ...        ...        ...     ...          ...
# 943          944      Male 2023-12-16       True  615401         14.7
# 976          977    Female 2024-01-03       True  373133         14.5
# 986          987      Male 2023-03-01      False  658885         14.7
# 989          990      Male 2024-02-23       True  332813         14.0
# 994          995    Female 2023-08-19      False  433879         14.3
#
#                    department
# 35                  Marketing
# 38                Engineering
# 53                  Marketing
# ...

# %% [markdown]
# Odstranění duplicit

# %%
employees.head()
# Out:
#    id_employee  gender start date  insurance  salary  rise_salary  \
# 0            1    Male 2023-11-26      False  356619          6.9
# 1            2  Female 2024-01-27       True  626147         13.0
# 2            3  Female 2023-03-30       True  332593          6.3
# 3            4    Male 2024-01-08       True  325067          9.9
# 4            5  Female 2024-04-15      False  667828         13.6
#
#            department
# 0             Support
# 1         Engineering
# 2             Support
# 3     Human Resources
# 4  Product Management

# %%
employees["department"].duplicated()    # True duplikát, False není duplikát
employees[employees["department"].duplicated()]   # True = vše jsou duplikáty
# Out:
#      id_employee      gender start date  insurance  salary  rise_salary  \
# 2              3      Female 2023-03-30       True  332593          6.3
# 6              7        Male 2024-01-19       True  375881          6.9
# 7              8        Male 2023-04-01      False  459264         12.6
# 8              9  Polygender 2023-10-09      False  694415          7.3
# 9             10  Non-binary 2023-05-25       True  439208          8.4
# ..           ...         ...        ...        ...     ...          ...
# 995          996      Female 2023-03-31      False  377851         12.0
# 996          997      Female 2024-01-05      False  620298         12.8
# 997          998         NaN 2024-03-16      False  361957         13.3
# 998          999        Male 2023-07-20      False  466946         12.6
# 999         1000        Male 2023-08-30       True  499784          7.4
#
#              department
# 2               Support
# 6           Engineering
# 7       Human Resources
# ...

# %%
employees["department"].duplicated(keep="first")
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: department, Length: 1000, dtype: bool

# %%
employees["department"].duplicated(keep="last")
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999    False
# Name: department, Length: 1000, dtype: bool

# %%
employees["department"].duplicated(keep=False)
employees[employees["department"].duplicated(keep=False)]
# Out:
#      id_employee  gender start date  insurance  salary  rise_salary  \
# 0              1    Male 2023-11-26      False  356619          6.9
# 1              2  Female 2024-01-27       True  626147         13.0
# 2              3  Female 2023-03-30       True  332593          6.3
# 3              4    Male 2024-01-08       True  325067          9.9
# 4              5  Female 2024-04-15      False  667828         13.6
# ..           ...     ...        ...        ...     ...          ...
# 995          996  Female 2023-03-31      False  377851         12.0
# 996          997  Female 2024-01-05      False  620298         12.8
# 997          998     NaN 2024-03-16      False  361957         13.3
# 998          999    Male 2023-07-20      False  466946         12.6
# 999         1000    Male 2023-08-30       True  499784          7.4
#
#              department
# 0               Support
# 1           Engineering
# 2               Support
# 3       Human Resources
# ...

# %%
employees["department"].duplicated(keep=False).unique()
# Out:
# array([ True])

# %%
employees["department"].unique()
# Out:
# array(['Support', 'Engineering', 'Human Resources', 'Product Management',
#        'Services', 'Marketing', 'Training', 'Accounting', 'Sales',
#        'Business Development', 'Research and Development', 'Legal'],
#       dtype=object)

# %%
employees[~employees["department"].duplicated(keep=False)]
# toto je znegování - ukáže hodhoty co nejsou duplikáty
# Out:
# Empty DataFrame
# Columns: [id_employee, gender, start date, insurance, salary, rise_salary, department]
# Index: []
