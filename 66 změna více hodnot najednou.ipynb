# %%
import pandas as pd

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col="Movie").sort_values("Year", ascending=False)
bond.head(3)
# Out:
#                    Year          Bond      Director       Composer  \
# Movie
# Spectre            2015  Daniel Craig    Sam Mendes  Thomas Newman
# Skyfall            2012  Daniel Craig    Sam Mendes  Thomas Newman
# Quantum of Solace  2008  Daniel Craig  Marc Forster   David Arnold
#
#                                                               Writer  \
# Movie
# Spectre            John Logan & Neal Purvis, Robert Wade & Jez Bu...
# Skyfall                        Neal Purvis, Robert Wade & John Logan
# Quantum of Solace        Paul Haggis and Neal Purvis and Robert Wade
#
#                      Cinematographer  \
# Movie
# Spectre            Hoyte van Hoytema
# Skyfall                Roger Deakins
# Quantum of Solace   Roberto Schaefer
#
#                                                    Depicted_Film_Loc  \
# Movie
# Spectre            Mexico, England, Italy, Austria, Morocco, Vati...
# Skyfall               Turkey, England, China, Macau, Japan, Scotland
# ...

# %%
bond["Bond"].replace("Daniel Craig", "David Šetek")
bond["Bond"] = bond["Bond"].replace("Daniel Craig", "David Šetek")

# %%
bond.head(3)
# Out:
#                    Year         Bond      Director       Composer  \
# Movie
# Spectre            2015  David Šetek    Sam Mendes  Thomas Newman
# Skyfall            2012  David Šetek    Sam Mendes  Thomas Newman
# Quantum of Solace  2008  David Šetek  Marc Forster   David Arnold
#
#                                                               Writer  \
# Movie
# Spectre            John Logan & Neal Purvis, Robert Wade & Jez Bu...
# Skyfall                        Neal Purvis, Robert Wade & John Logan
# Quantum of Solace        Paul Haggis and Neal Purvis and Robert Wade
#
#                      Cinematographer  \
# Movie
# Spectre            Hoyte van Hoytema
# Skyfall                Roger Deakins
# Quantum of Solace   Roberto Schaefer
#
#                                                    Depicted_Film_Loc  \
# Movie
# Spectre            Mexico, England, Italy, Austria, Morocco, Vati...
# Skyfall               Turkey, England, China, Macau, Japan, Scotland
# ...
