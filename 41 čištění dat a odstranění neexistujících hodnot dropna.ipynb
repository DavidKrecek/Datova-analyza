# %%
import pandas as pd

# %%
bank_users = pd.read_csv("data/bank_users.csv")
bank_users.head(3)
# Out:
#   first_name last_name                 email  bank_account  born_year  \
# 0      Shawn     Gotts  sgotts0@newsvine.com          58.0        NaN
# 1   Sergeant    Linsey       slinsey1@qq.com          70.0     2007.0
# 2   Ambrosio    Gorton    agorton2@google.es          48.0     2000.0
#
#                     city
# 0               Jinchuan
# 1                Tāngāil
# 2  Zhushan Chengguanzhen

# %%
bank_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    200 non-null    object
#  1   last_name     200 non-null    object
#  2   email         192 non-null    object
#  3   bank_account  179 non-null    float64
#  4   born_year     176 non-null    float64
#  5   city          187 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 9.5+ KB

# %%
clean_data = bank_users.dropna()
clean_data
# Out:
#     first_name  last_name                           email  bank_account  \
# 1     Sergeant     Linsey                 slinsey1@qq.com          70.0
# 2     Ambrosio     Gorton              agorton2@google.es          48.0
# 3         Gram   Steanyng            gsteanyng3@google.fr          92.0
# 4        Britt   Cockaday                 bcockaday4@t.co          78.0
# 5       Onfroi   Simonett  osimonett5@businessinsider.com          58.0
# ..         ...        ...                             ...           ...
# 193      Perle  Gavrielly      pgavrielly5d@123-reg.co.uk          56.0
# 194    Brennan       Stow                  bstow5e@w3.org          29.0
# 195      Franz       Oppy          foppy5f@shutterfly.com          90.0
# 196   Adolphus    Labbati       alabbati5g@yellowbook.com          56.0
# 198  Armstrong   Laughren         alaughren5i@yahoo.co.jp          87.0
#
#      born_year                      city
# 1       2007.0                   Tāngāil
# ...

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140 entries, 1 to 198
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    140 non-null    object
#  1   last_name     140 non-null    object
#  2   email         140 non-null    object
#  3   bank_account  140 non-null    float64
#  4   born_year     140 non-null    float64
#  5   city          140 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 7.7+ KB

# %%
clean_data_2 = bank_users.dropna(how="any")
clean_data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140 entries, 1 to 198
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    140 non-null    object
#  1   last_name     140 non-null    object
#  2   email         140 non-null    object
#  3   bank_account  140 non-null    float64
#  4   born_year     140 non-null    float64
#  5   city          140 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 7.7+ KB

# %%
clean_data_3 = bank_users.dropna(how="all")
clean_data_3
# Out:
#     first_name last_name                      email  bank_account  born_year  \
# 0        Shawn     Gotts       sgotts0@newsvine.com          58.0        NaN
# 1     Sergeant    Linsey            slinsey1@qq.com          70.0     2007.0
# 2     Ambrosio    Gorton         agorton2@google.es          48.0     2000.0
# 3         Gram  Steanyng       gsteanyng3@google.fr          92.0     1970.0
# 4        Britt  Cockaday            bcockaday4@t.co          78.0     1985.0
# ..         ...       ...                        ...           ...        ...
# 195      Franz      Oppy     foppy5f@shutterfly.com          90.0     2020.0
# 196   Adolphus   Labbati  alabbati5g@yellowbook.com          56.0     1984.0
# 197    Aurelea   Cordery        acordery5h@furl.net           NaN     1992.0
# 198  Armstrong  Laughren    alaughren5i@yahoo.co.jp          87.0     1983.0
# 199  Henrietta   Peckitt    hpeckitt5j@multiply.com           NaN     1967.0
#
#                       city
# ...

# %%
clean_data_4 = bank_users.dropna(subset=["born_year"])
clean_data_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 176 entries, 1 to 199
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    176 non-null    object
#  1   last_name     176 non-null    object
#  2   email         168 non-null    object
#  3   bank_account  157 non-null    float64
#  4   born_year     176 non-null    float64
#  5   city          165 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 9.6+ KB

# %%
clean_data_5 = bank_users.dropna(subset=["bank_account", "born_year"])
clean_data_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 1 to 198
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    157 non-null    object
#  1   last_name     157 non-null    object
#  2   email         149 non-null    object
#  3   bank_account  157 non-null    float64
#  4   born_year     157 non-null    float64
#  5   city          147 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 8.6+ KB

# %%
bank_users.size
# Out:
# 1200

# %%
bank_users.dropna().size
# Out:
# 840

# %%
bank_users.size - bank_users.dropna().size
# Out:
# 360

# %%
bank_users.dropna(subset=["born_year"]).size
# Out:
# 1056

# %%
bank_users.size - bank_users.dropna(subset=["born_year"]).size
# Out:
# 144

# %%
bank_users.dropna(subset=["email"]).size
# Out:
# 1152

# %%
bank_users.size - bank_users.dropna(subset=["email"]).size
# Out:
# 48

# %%
48/6        # počet chybějících hodnot v mailech - protože to vždy odstraní 6 buněk s celým řádkem
# Out:
# 8.0

# %% [markdown]
# Dotaz, kolik je chybějících hodnot ve sloupci "bank_account" a zároveň ve sloupci "born_year"?

# %%
bank_users.size # 1200
bank_users.size - bank_users.dropna(subset=["bank_account"]).size # 126 odstranil buněk
bank_users.size - bank_users.dropna(subset=["born_year"]).size # 144 odstranil buněk
bank_users.size - bank_users.dropna(subset=["bank_account", "born_year"]).size # odstranil 258 buněk
# Out:
# 258

# %%
126 + 144
270 - 258
# Out:
# 12

# %%
12 / 6
# Out:
# 2.0
