# %%
import pandas as pd

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col="Movie").sort_index()
bond.head(3)
# Out:
#                       Year          Bond         Director      Composer  \
# Movie
# A View to a Kill      1985   Roger Moore        John Glen    John Barry
# Casino Royale         2006  Daniel Craig  Martin Campbell  David Arnold
# Diamonds Are Forever  1971  Sean Connery     Guy Hamilton    John Barry
#
#                                                       Writer Cinematographer  \
# Movie
# A View to a Kill         Michael G. Wilson & Richard Maibaum       Alan Hume
# Casino Royale         Neal Purvis, Robert Wade & Paul Haggis     Phil Méheux
# Diamonds Are Forever        Richard Maibaum & Tom Mankiewicz       Ted Moore
#
#                                                       Depicted_Film_Loc  \
# Movie
# A View to a Kill           Russia, Great Britain, France, United States
# Casino Royale         Czech Republic, Pakistan, Uganda, Madagascar, ...
# Diamonds Are Forever  Japan, Egypt, France, South Africa, Great Brit...
#
# ...

# %% [markdown]
# Změna jedné hodnoty

# %%
# # špatný přístup - pozor, upravujeme původní, tj. view
# bond["Bond"]
# bond["Bond"].loc["Casino Royale"] = "David Šetek"
# bond["Bond"]

# %%
# správný přístup - pomocí polohy - label a sloupec
bond.loc["Casino Royale", "Bond"] = "David Šetek"
bond.loc["Casino Royale", "Bond"]
# Out:
# 'David Šetek'
