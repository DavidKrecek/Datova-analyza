# %%
import pandas as pd

# %%
# bond = pd.read_csv("data/jamesbond.csv", index_col="Movie")
# bond.head(3)
bond = pd.read_csv("data/jamesbond.csv")
bond.head(3)
# Out:
#    Year                  Movie          Bond       Director      Composer  \
# 0  1962                 Dr. No  Sean Connery  Terence Young  Monty Norman
# 1  1963  From Russia with Love  Sean Connery  Terence Young    John Barry
# 2  1964             Goldfinger  Sean Connery   Guy Hamilton    John Barry
#
#                                               Writer Cinematographer  \
# 0  Richard Maibaum, Johanna Harwood & Berkely Mather       Ted Moore
# 1                  Richard Maibaum & Johanna Harwood       Ted Moore
# 2                        Richard Maibaum & Paul Dehn       Ted Moore
#
#                                    Depicted_Film_Loc  \
# 0                              Great Britain, Jamaic
# 1  United Kingdom, Great Britain, Turkey, Croatia...
# 2          United States, Great Britain, Switzerland
#
#                                     Shooting_Loc  Bond_Car_MFG  ...  \
# 0                               England, Jamaica       Sunbeam  ...
# ...

# %%
james_bond = bond.set_index("Movie")
james_bond.head(3)

james_bond.reset_index()
james_bond.reset_index(drop=False)
james_bond.reset_index(drop=True)
james_bond.head(3)
# Out:
#                        Year          Bond       Director      Composer  \
# Movie
# Dr. No                 1962  Sean Connery  Terence Young  Monty Norman
# From Russia with Love  1963  Sean Connery  Terence Young    John Barry
# Goldfinger             1964  Sean Connery   Guy Hamilton    John Barry
#
#                                                                   Writer  \
# Movie
# Dr. No                 Richard Maibaum, Johanna Harwood & Berkely Mather
# From Russia with Love                  Richard Maibaum & Johanna Harwood
# Goldfinger                                   Richard Maibaum & Paul Dehn
#
#                       Cinematographer  \
# Movie
# Dr. No                      Ted Moore
# From Russia with Love       Ted Moore
# Goldfinger                  Ted Moore
#
#                                                        Depicted_Film_Loc  \
# Movie
# Dr. No                                             Great Britain, Jamaic
# ...

# %%
james_bond = bond.set_index("Movie")
james_bond.set_index("Year").head(3)
# Out:
#               Bond       Director      Composer  \
# Year
# 1962  Sean Connery  Terence Young  Monty Norman
# 1963  Sean Connery  Terence Young    John Barry
# 1964  Sean Connery   Guy Hamilton    John Barry
#
#                                                  Writer Cinematographer  \
# Year
# 1962  Richard Maibaum, Johanna Harwood & Berkely Mather       Ted Moore
# 1963                  Richard Maibaum & Johanna Harwood       Ted Moore
# 1964                        Richard Maibaum & Paul Dehn       Ted Moore
#
#                                       Depicted_Film_Loc  \
# Year
# 1962                              Great Britain, Jamaic
# 1963  United Kingdom, Great Britain, Turkey, Croatia...
# 1964          United States, Great Britain, Switzerland
#
#                                        Shooting_Loc  Bond_Car_MFG  \
# Year
# 1962                               England, Jamaica       Sunbeam
# 1963  England, Scotland, Italy, Switzerland, Turkey        Bently
# ...

# %%
james_bond = bond.set_index("Movie")
james_bond.reset_index().set_index("Year")
# Out:
#                                 Movie            Bond            Director  \
# Year
# 1962                           Dr. No    Sean Connery       Terence Young
# 1963            From Russia with Love    Sean Connery       Terence Young
# 1964                       Goldfinger    Sean Connery        Guy Hamilton
# 1965                      Thunderball    Sean Connery       Terence Young
# 1967              You Only Live Twice    Sean Connery       Lewis Gilbert
# 1969  On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt
# 1971             Diamonds Are Forever    Sean Connery        Guy Hamilton
# 1973                 Live and Let Die     Roger Moore        Guy Hamilton
# 1974      The Man with the Golden Gun     Roger Moore        Guy Hamilton
# 1977             The Spy Who Loved Me     Roger Moore       Lewis Gilbert
# 1979                        Moonraker     Roger Moore       Lewis Gilbert
# 1981               For Your Eyes Only     Roger Moore           John Glen
# ...
